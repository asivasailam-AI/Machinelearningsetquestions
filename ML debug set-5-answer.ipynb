# %%
#1.
import pandas as pd

df = pd.DataFrame({'a': [1, 2, None, 4]})
df.fillna(0)
print(df)

# %%
#1.
import pandas as pd

df = pd.DataFrame({'a': [1, 2, None, 4]})
df.fillna(0)
print(df)
# Out:
#      a
# 0  1.0
# 1  2.0
# 2  NaN
# 3  4.0

# %%
#2.
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])

# %%
#3.
from sklearn.naive_bayes import GaussianNB

X = [[1, 2], [3, 4]]
y = [0, 1]

model = GaussianNB()
model.fit(X, y)
print(model.predict([[2, 3]])) #Gaussian NB can process only numeric data
# Out:
# [0]

# %%
#4.
import seaborn as sns

tips = sns.load_dataset("tips")
sns.barplot(x="day", y="tip", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#5.
from sklearn.metrics import confusion_matrix

y_true = [0, 1, 2, 2]
y_pred = [0, 0, 2, 2]

print(confusion_matrix(y_true, y_pred, labels=[0, 1]))
# Out:
# [[1 0]
#  [1 0]]

# %%
#6.
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(['cat', 'dog', 'mouse'])
print(le.transform(['dog']))
# Out:
# [1]

# %%
#7.
from sklearn.impute import SimpleImputer
import numpy as np

X = np.array([[1, 2], [np.nan, 3], [7, 6]])

imp = SimpleImputer(strategy='mean')
imp.fit(X)
print(imp.transform([[np.nan, 3]]))
# Out:
# [[4. 3.]]

# %%
#8.
import pandas as pd

df = pd.read_csv('/Users/siva/Downloads/Mall_Customers.csv')  #missing dat set is not found
print(df.head())
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#9.
import numpy as np

a = np.array([1, 2, 3])
b = np.array([[1], [2], [3]])

print(np.dot(a, b))
# Out:
# [14]

# %%
#10.
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit([[1], [2], [3]], [1, 2, 3])# input features to match output features
# Out:
# LinearRegression()
