# %%
#1.The following code throws an error. What is wrong?
import tensorflow as tf
model = keras.Sequential()  # Error here

# %%
# !pip install tensorflow 
from tensorflow import keras
model = keras.Sequential()  # Installed tensor flow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (25.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.81.1-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Downloading keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./anaconda3/lib/python3.13/site-packages (from tensorflow) (2.3.5)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./anaconda3/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in ./anaconda3/lib/python3.13/site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (32 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./anaconda3/lib/python3.13/site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.13/site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp313-cp313-macosx_12_0_arm64.whl (223.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 MB 10.0 MB/s  0:00:22 eta 0:00:010:00:01
# Downloading grpcio-1.81.1-cp313-cp313-macosx_11_0_universal2.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 10.6 MB/s  0:00:01 10.7 MB/s eta 0:00:01
# Downloading h5py-3.14.0-cp313-cp313-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.5 MB/s  0:00:00 11.4 MB/s eta 0:00:01
# Downloading ml_dtypes-0.5.4-cp313-cp313-macosx_10_13_universal2.whl (676 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 8.7 MB/s  0:00:00
# Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl (433 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.14.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.0 MB/s  0:00:00
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 10.5 MB/s  0:00:02 10.6 MB/s eta 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.1-cp313-cp313-macosx_11_0_arm64.whl (398 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, protobuf, optree, opt_einsum, ml_dtypes, h5py, grpcio, google_pasta, gast, astunparse, absl-py, keras, tensorflow
#   Attempting uninstall: protobuf2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [libclang]
#     Found existing installation: protobuf 5.29.338;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [libclang]
#     Uninstalling protobuf-5.29.3:;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [libclang]
#       Successfully uninstalled protobuf-5.29.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [libclang]
#   Attempting uninstall: h5py━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [opt_einsum]]
#     Found existing installation: h5py 3.15.137m╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [opt_einsum]
#     Uninstalling h5py-3.15.1:━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  8/16 [h5py]m]
#       Successfully uninstalled h5py-3.15.1╺━━━━━━━━━━━━━━━━━━━  8/16 [h5py]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [tensorflow]37m━━ 15/16 [tensorflow]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.51.0 requires protobuf<7,>=3.20, but you have protobuf 7.35.1 which is incompatible.
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.81.1 h5py-3.14.0 keras-3.14.1 libclang-18.1.1 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.1 protobuf-7.35.1 tensorflow-2.21.0 termcolor-3.3.0

# %%
#2.
from sklearn.svm import SVC
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

model = SVC()
model.fit(X, y)  # Error

# %%
from sklearn.svm import SVR
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

model = SVR()
model.fit(X, y)  # Error

# %%
#3.
from sklearn.tree import RandomForestClassifier  # Incorrect import
clf = RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier  # Corrected import
clf = RandomForestClassifier()

# %%
#4.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = [[1, 2], [3, 4], [5, 6], [7, 8]]
y = [0, 1, 0, 1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)  # Error

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = [[1, 2], [3, 4], [5, 6], [7, 8]]
y = [0, 1, 0, 1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)  # Error

# %%
#5.
import pandas as pd
df = pd.DataFrame({'age': [25, 30, 35], 'salary': [50000, 60000, 70000]})
print(df['salry'])  # Typo

# %%
import pandas as pd
df = pd.DataFrame({'age': [25, 30, 35], 'salary': [50000, 60000, 70000]})
print(df['salary'])  # Typo
# Out:
# 0    50000
# 1    60000
# 2    70000
# Name: salary, dtype: int64

# %%
#6.import pandas as pd
df = pd.DataFrame({'Age': ['25', '30', '35']})  # Stored as string
print(df['Age'].mean())

# %%
#6.import pandas as pd
df = pd.DataFrame({'Age': ['25', '30', '35']})  # Stored as string
df['Age'] = pd.to_numeric(df['Age'])
print(df['Age'].mean())
# Out:
# 30.0

# %%
#7.
def add_numbers(a, b):
result = a + b
 return result

# %%
def add_numbers(a, b):
 result = a + b
 return result

# %%
#8.
from sklearn.model_selection import train_test_split
X = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0]  # Mismatched length
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.model_selection import train_test_split
X = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0, 1]  # Mismatched length
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#9.
print(my_name)
my_name = "Alice"

# %%
my_name = "Alice"
print(my_name)
# Out:
# Alice

# %%
#10.
import pandas as pd

df = pd.DataFrame({'Age': [25, 30, 35, 40]})
df['Age_Category'] = df['Age'].apply(lambda x: 'Young' if x < 30 'Old')  # Error

# %%
import pandas as pd

df = pd.DataFrame({'Age': [25, 30, 35, 40]})
df['Age_Category'] = df['Age'].apply(lambda x: 'Young' if x < 30  else'Old')  # Error
