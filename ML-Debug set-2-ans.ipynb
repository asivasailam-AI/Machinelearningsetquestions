# %%
#1.Why does this train-test split fail?
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.2, random_state=42)

# %%
#2.
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = [0, 1, 0]

model = DecisionTreeClassifier(max_depth=100)
model.fit(X, y)
print(model.score(X, y))
# Out:
# 1.0

# %%
#3.
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])

model = KMeans(n_clusters=3)
model.fit(X)
print(model.predict([[2,3]]))
# Out:
# [0]

# %%
#4.
import pandas as pd  

df = pd.DataFrame({'A': [1, 2, 3]})
print(df)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
#5.from sklearn.tree import DecisionTreClassifier  # Typo in 'DecisionTreeClassifier'

from sklearn.tree import DecisionTreeClassifier  # Typo in 'DecisionTreeClassifier'

model = DecisionTreeClassifier()

# %%
#6.
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=3)

# %%
#7.
from sklearn.linear_model import LinearRegression

X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

model = LinearRegression()
model.fit(X, y)

print(model.predict([[4,1]]))  # Incorrect attribute name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 10
#       7 model = LinearRegression()
#       8 model.fit(X, y)
# ---> 10 print(model.predict([[4,1]]))  # Incorrect attribute name
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/linear_model/_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)    309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/linear_model/_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/utils/validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/utils/validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 2 features, but LinearRegression is expecting 1 features as input.

# %%
#8.
from sklearn.neighbors import KNeighborsClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = KNeighborsClassifier(n_neighbors=0)  # Invalid value for n_neighbors
model.fit(X_train, y_train)

# %%
#9.
import pandas as pd

df = pd.DataFrame({'A': [10, 20, 30], 'B': [1, 2, 3]})
print(df.iloc['A'])  # Incorrect: iloc requires integer indexes

# %%
#10.
from sklearn.ensemble import RandomForestClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = RandomForestClassifier()
model.fit(X_train, y_train)

probs = model.predict_proba([[2, 3]])[1]  # Incorrect index
print(probs)
